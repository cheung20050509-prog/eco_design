# %%
"""
【示例1】数值型变量应用。
"""
# 定义交易次数
trade_times = 20 
# 定义交易胜率
win_rate = 0.72
# 打印变量数据类型
print("trade_times的数据类型为：", type(trade_times))
print("win_rate的数据类型为：", type(win_rate))
# Out:
# trade_times的数据类型为： <class 'int'>
# win_rate的数据类型为： <class 'float'>

# %%
"""
【示例2】布尔类型变量应用。
"""
# 设置止盈价格变量名为price_win
price_win = 10.00
# 设置现价变量名为price_now
price_now = 9.85
# 如果现价price_now大于止盈价格price_win
if  price_now > price_win:
    # 变量win_value被赋值为True
    win_value = True
# 否则
else:
    # 变量win_value被赋值为False 
    win_value= False
    # 打印变量win_value
    print("win_value 的值为：", win_value)
# Out:
# win_value 的值为： False

# %%
"""
【示例3】字符串类型变量应用。
"""
#定义股票名称
stock_name = '贵州茅台'
#定义股票代码
stock_code = 'SH.600519'
# 定义带格式的字符串变量
a = '''
    公司股票：浦发银行  贵州茅台
    行    业：银行业    白酒行业
'''

# %%
"""
【示例4】str.find函数应用。
"""
# 在股票代码变量stock_code中查找是否包含字符串“SH”
print(stock_code.find('SH'))
#在股票代码变量stock_code中查找是否包含“SZ”
print(stock_code.find('SZ'))
# Out:
# 0
# -1

# %%
"""
【示例5】str.replace函数应用。
"""
# 将股票代码变量stock_code中的“SH”替换为“沪市”
print(stock_code.replace('SH', '沪市'))
# Out:
# 沪市.600519

# %%
"""
【示例6】str.strip函数应用。
"""

# 将股票代码变量stock_code中的“SH.”删除
print(stock_code.strip('SH.'))
# Out:
# 600519

# %%
"""
【示例7】str.join函数应用。
"""
# 定义列表变量，元素为字符串类型数据。
date_list = ['2023', '1', '15']
# 设置连接符号变量，为字符串类型数据。
string1 = '-'
# 将date_list内部元素使用string1进行连接，生成一个新的字符串类型数据。
string1.join(date_list)
# Out:
# '2023-1-15'

# %%
"""
【示例8】str.count函数应用。
"""
# 统计字符串类型变量stock_list中含有“SH”的个数
stock_list = ' SH.600000 SH.600519 SH.600188 '
#在字符串变量stock_list中出现“SH”的次数
stock_list . count ( 'SH' )
# Out:
# 3

# %%
"""
【示例9】创建列表。
"""
# 定义一个存储开盘价序列的列表变量open_list
open_list = [10.12, 10.58, 11.00, 13.25]
# 定义一个存储股票代码的列表变量stock_list
stock_list = ['SH.600000', 'SZ.000001', 'SH.600188' ]

# %%
"""
【示例10】list.append方法应用。
"""

# 在列表变量stock_list末尾添加元素"SZ.000007"
stock_list.append('SZ.000007')
# 打印输出添加元素“SZ.000007”后的列表stock_list
print(stock_list)
# Out:
# ['SH.600000', 'SZ.000001', 'SH.600188', 'SZ.000007']

# %%
"""
【示例11】list.insert方法应用。
"""
# 在列表变量stock_list第2个位置（列表的索引号也是从0开始的）插入元素“SH.600188”
stock_list.insert(1, 'SH.600188')
# 打印输出插入新元素后的列表stock_list
print(stock_list)
# Out:
# ['SH.600000', 'SH.600188', 'SZ.000001', 'SH.600188', 'SZ.000007']

# %%
"""
【示例12】list.remove方法应用。
"""
# 从列表变量stock_list中删除元素“SZ.000007”
stock_list.remove('SZ.000007')
# 打印输出删除元素“SZ.000007”后的列表stock_list
print(stock_list)
# Out:
# ['SH.600000', 'SH.600188', 'SZ.000001', 'SH.600188']

# %%
"""
【示例13】list.pop方法应用。
"""
stock_list.pop(1)
# 从列表变量stock_list中删除第二个元素
# Out:
# 'SH.600188'

# %%
"""
【示例14】list.count方法应用。
"""
# 统计列表变量stock_list中“SH.600000”出现的次数
times = stock_list.count('SH.600000')
# 打印输出列表stock_list中包含“SH.600000”的次数
print('SH.600000在列表中出现的次数：', times)
# Out:
# SH.600000在列表中出现的次数： 1

# %%
"""
【示例15】按stock_list元素的数字部分升序排序。
"""
# 定义函数
def get_stock_num(stock_code):
	#返回从第4个字符开始到最后一个字符，即股票代码
	return stock_code[3:]
     
# 列表对象按逆序，将函数get_stock_num函数返回值进行排序
stock_list.sort(key=get_stock_num, reverse=False)
# 打印排序后的列表变量
print(stock_list)
# Out:
# ['SZ.000001', 'SH.600000', 'SH.600188']

# %%
"""
【示例16】元组变量赋值与内部元素读取。
"""
# 定义并赋值元祖类型的变量stock_tuple_1，内部有多个元素。
stock_tuple_1 = ('贵州茅台', '中国石化', '工商银行')
# 定义并赋值元祖类型的变量stock_tuple_2，内部只有一个元素。
stock_tuple_2 = ('赢时胜',)
# 元组元素的读取。
print('stock_tuple_1第3个元素为：', stock_tuple_1[2])
# 两个元祖变量的数学运算。
stock_tuple_3 = stock_tuple_1 + stock_tuple_2
print('stock_tuple_1 + stock_tuple_2生成的元组变量stock_tuple_3为：', stock_tuple_3)
# Out:
# stock_tuple_1第3个元素为： 工商银行
# stock_tuple_1 + stock_tuple_2生成的元组变量stock_tuple_3为： ('贵州茅台', '中国石化', '工商银行', '赢时胜')

# %%
"""
【示例17】创建集合类型变量。
"""
# 定义集合类型变量
stock_set1 = {'贵州茅台', '中国石化', '工商银行'} 
# 打印集合类型变量stock_set1
print(stock_set1)

# 定义集合类型变量
stock_set2 = set(stock_list)
# 打印集合类型变量stock_set2
print(stock_set2)
# Out:
# {'贵州茅台', '工商银行', '中国石化'}
# {'SH.600188', 'SZ.000001', 'SH.600000'}

# %%
"""
【示例18】创建字典。
"""
#定义字典类型变量stock_info_dict
stock_dict = {'stock_name':'贵州茅台', 'date':'2023-01-16', 'price':1912.90}
# 打印字典类型变量stock_info_dict
print(stock_dict)
# Out:
# {'stock_name': '贵州茅台', 'date': '2023-01-16', 'price': 1912.9}

# %%
"""
【示例19】逻辑运算符应用。
"""
# 设置两个条件，分别为con1与con2
# 条件con1表示字典stock_dict的键name对应的值为“贵州茅台”
con1 = stock_dict['stock_name'] == '贵州茅台'
# 条件con2表示字典stock_dict的键trade_date对应的值为“20230120”
con2 = stock_dict['date']=='20230116'
# 打印结果：con1与con2同时为真
print(con1 and con2 )
# 打印结果：stock_dict['trade_date']=='20230121'为假
print(stock_dict['stock_name']=='贵州茅台' and stock_dict['date']=='2023-01-16')
# Out:
# False
# True

# %%
"""
【示例20】单一条件判断流程应用。
"""
# 买入价为10元
buy = 10   
# 收盘价为9元
close = 9  
# 如果收盘价大于买入价的1.1倍
if  close > buy * (1+0.1): 
    print('卖出')         
# 否则
else:
    print('继续持有')
# Out:
# 继续持有

# %%
"""
【示例21】多条件判断流程应用。
"""
# 条件1：如果收盘价大于买入价的1.2倍
if  buy * (1+0.2) < close: 
    print("太棒了！！上涨幅度超过20% ！")     
# 条件2：如果收盘价大于买入价，小于买入价的1.2倍
elif  buy * (1+0.2) >= close>buy:
    print("还可以！！上涨幅度小于20% ！")   
# 条件3：其余情形（否则）
else:
    print("没有上涨！")
# Out:
# 没有上涨！

# %%
"""
【示例22】利用for循环将列表内的股票名称全部打印。
"""
# 创建列表变量“stock_buy_list”，存储需要买入的股票名称
stock_buy_list = ['贵州茅台', '工商银行', '老白干', '复星医药']   
# 使用for循环遍历列表变量“stock_buy_list”内部每一个元素
for stock_name in stock_buy_list:
    # 打印列表变量“stock_buy_list”内部每一个元素
    print(stock_name)
# Out:
# 贵州茅台
# 工商银行
# 老白干
# 复星医药

# %%
"""
【示例23】利用while循环将列表内的股票名称逐个打印出来。
"""
# 设置计数器，初始值为0
i = 0                                                          
# 当计数器小于“stock _ buy _ list”列表长度时，则执行“while”循环内部语句
while i < len(stock_buy_list):                                
    # 打印stock_name 
    print(stock_buy_list[i])                                  
    # 计算器加1
    i += 1
# Out:
# 贵州茅台
# 工商银行
# 老白干
# 复星医药

# %%
"""
【示例24】打印列表内的股票名称，“工商银行”除外。
"""
# 使用for循环遍历列表变量“stock_buy_list”内部每一个元素
for stock_name in stock_buy_list:                           
    # 设置执行“continue”语句的逻辑判断条件
    # 当遇到循环至“工商银行”时，则跳出本次循序，执行下一次循环
    if stock_name == '工商银行':                            
        continue 
    print(stock_name)
# Out:
# 贵州茅台
# 老白干
# 复星医药

# %%
"""
【示例25】定义计算股票的收益率函数。
"""
# 定义函数calculate_return_ratio
# 参数：buy_price与sell_price
def calculate_return_ratio(buy_price, sell_price):
    return_ratio = sell_price / buy_price - 1
    return return_ratio

# 定义buyprice变量，存储买入价格。
buyprice = 10                                       
# 定义sellprice变量，存储卖出价格。
sellprice = 11                                       
# 设置变量investratio保存caculate_return_ratio函数返回值。
investratio = calculate_return_ratio(buyprice, sellprice)
# 打印函数返回值。
print(investratio)
# Out:
# 0.10000000000000009

# %%
"""
【示例26】元祖类型可变参数应用。
"""
# 函数my_function的形式参数为元祖类型的可变参数
def my_function(*args):
    print(*args)
    
# 调用函数my_function，直接元祖类型的实际#参数
my_function(1, 2)
# Out:
# 1 2

# %%
"""
【示例27】字典类型可变参数应用。
"""
# 函数my_function的形式参数为字典类型的可变参数
def my_function(**kwargs):
    print(kwargs)
    
# 调用函数my_function，传入字典类型实际参数
my_function(price=10, volume=300)
# Out:
# {'price': 10, 'volume': 300}

# %%
"""
【示例28】lambda匿名函数应用。
"""
# 创建匿名函数，并将返回值赋给add变量
add = lambda x, y: x + y

# 调用lambda匿名函数，并传入实际参数3、5给匿名函数中的x与y形式参数
result = add(3, 5)
print(result)
# Out:
# 8

# %%
"""
【示例29】map函数应用：根据price列表元素计算收益率。
"""
# 创建浮点类型数据的列表price
prices = [100.0, 105.5, 110.2, 108.0, 112.3, 115.5]
# 计算price列表内部元素之间的涨跌幅
returns = map(lambda p:round((p-prices[0])/prices[0], 2), prices)
print(list(returns))
# Out:
# [0.0, 0.06, 0.1, 0.08, 0.12, 0.15]

# %%
"""
【示例30】filter函数应用：从股票列表中筛选出深市股票代码。
"""
# 创建股票代码列表stocks_list
stocks_list= ['60000.SS','000001.SZ','600004.SS','600519.ss', '000032.sz']
# 在股票代码列表stocks_list中筛选出结尾是“SS”的股票代码，并保存至stocks_SS列表
stocks_SS = filter(lambda x: x[-2:].upper() == 'SS', stocks_list)
print(list(stocks_SS))
# Out:
# ['60000.SS', '600004.SS', '600519.ss']

# %%
"""
【示例31】filter函数应用：筛选符合条件的股票。
"""
# 定义stock变量为元素为字典的列表类型数据
stocks = [
    {'symbol': 'AAPL', 'pe_ratio': 31.24, 'dividend_yield': 1.24},
    {'symbol': 'GOOG', 'pe_ratio': 27.35, 'dividend_yield': 0.78},
    {'symbol': 'MSFT', 'pe_ratio': 35.12, 'dividend_yield': 0.87},
    {'symbol': 'AMZN', 'pe_ratio': 76.43, 'dividend_yield': 0},
]

# 筛选出市盈率低于35的股票
low_pe_stocks = filter(lambda stock: stock['pe_ratio'] > 35, stocks)
print(r'出市盈率低于30的股票：{}'.format(list(low_pe_stocks)))

# 筛选出股息率高于1%的股票
high_dividend_stocks = filter(lambda stock: stock['dividend_yield'] > 1, stocks)
print(r'股息率高于1%的股票：{}'.format(list(high_dividend_stocks)))
# Out:
# 出市盈率低于30的股票：[{'symbol': 'MSFT', 'pe_ratio': 35.12, 'dividend_yield': 0.87}, {'symbol': 'AMZN', 'pe_ratio': 76.43, 'dividend_yield': 0}]
# 股息率高于1%的股票：[{'symbol': 'AAPL', 'pe_ratio': 31.24, 'dividend_yield': 1.24}]

# %%
"""
【示例32】filter函数应用：数据清洗之剔除空值与与异常值。
"""
# 创建含有空值None的列表data
data = [0.5, 0.3, None, 0.7, 0.2, 21.2, 0.6, None, 0.9, 1.0]
# 剔除data列表中空值
clean_data = list(filter(lambda x: x is not None, data))
print(r'去除空值None之后的序列：{}'.format(clean_data))

# 剔除异常值（偏离均值超过2倍标准差的值）
# 计算均值
mean = sum(clean_data) / len(clean_data)
# 计算标准差
std_dev = (sum((x - mean) ** 2 for x in clean_data) / len(clean_data)) ** 0.5

# 剔除偏离均值超过2倍标准差的值
filtered_data = filter(lambda x: abs(x - mean) <= 2 * std_dev, clean_data)
print(r'去除异常值后的序列：{}'.format(list(filtered_data)))
# Out:
# 去除空值None之后的序列：[0.5, 0.3, 0.7, 0.2, 21.2, 0.6, 0.9, 1.0]
# 去除异常值后的序列：[0.5, 0.3, 0.7, 0.2, 0.6, 0.9, 1.0]

# %%
"""
【示例33】reduce函数应用：计算列表元素加总求和。
"""
# 导入 functools 模块中的 reduce 函数
from functools import reduce

# 创建整数型列表numbers
numbers = [1, 2, 3, 4, 5]
# 计算列表numbers内部元素的总行
product = reduce(lambda x, y: x + y, numbers, 20)
print(product)
# Out:
# 35

# %%
"""
【示例34】reduce函数应用：基于每日收益率计算累计收益率。
"""
from functools import reduce

# 创建收益率列表returns
returns = [0.1, 0.2, 0.3]
# 以returns列表内部元素为每期收益率，计算returns列表累计收益率
cumulative_return = reduce(lambda x, y: x * (1 + y), returns, 1) - 1
print(cumulative_return)
# Out:
# 0.7160000000000002

# %%
"""
【示例35】reduce函数应用：计算投资组合加权平均收益率。
"""
"""
这是一个使用reduce函数计算投资组合加权平均收益率的示例：
假设持有三个资产 A、B、C：
收益率：10%、 20%、 30%；
权 重： 0.3、 0.4、 0.3。
现计算这个投资组合的加权平均收益率：
"""
from functools import reduce

# 三个资产 A、B、C的收益率存放于returns列表
returns = [0.1, 0.2, 0.3]
# 三个资产 A、B、C的权重存放于weights
weights = [0.3, 0.4, 0.3]
# 计算三个资产 A、B、C实际收益率，存放于weighted_returns列表
weighted_returns = [r * w for r, w in zip(returns, weights)]
# 通过reduce函数计算三个资产 A、B、C组合实际收益率
weighted_average_return = reduce(lambda x, y: x + y, weighted_returns) / sum(weights)
print(weighted_average_return)
# Out:
# 0.2

# %%
"""
【示例36】调用os模块方法。
"""
# 引入os模块	
import os
# 调用os模块的listdir函数，读取“D:/”盘全部文件名称，存入列表变量
file_name_list = os.listdir('D:/')

# %%
"""
【示例37】datetime模块应用1。
"""
from datetime import date, time, datetime, timedelta, timezone

# date 类的today方法
today = date.today()
print(f"1---date.today()：今天的日期是{today}")

# 生成日期变量（仅含有年月日）
specific_date = date(2022, 1, 1)
print(f"2---date(2022, 1, 1)：特定的日期是{specific_date}")

# 返回日期为周几
day_of_week = today.weekday()
print(f"3---today.weekday()：今天是一周中的第 {day_of_week + 1} 天")

# 使用time 类方法，生成时间变量（包含小时、分钟、秒）
current_time = time(14, 30, 45)
print(f"4---time(14, 30, 45)：特定的时间是{current_time}")

# 使用datetime 类的now方法获取当前时间
now = datetime.now()
print(f"5---datetime.now()：现在的日期和时间是{now}")

# 构建datetime实例（包含年、月、日、时、分、秒）
specific_datetime = datetime(2022, 1, 1, 14, 30, 45)
print(f"6---datetime(2022, 1, 1, 14, 30, 45)：特定的日期和时间是{specific_datetime}")

# 将datetime对象按指定格式转成文本形式
specific_datetime_format = specific_datetime.strftime(format='%Y/%m/%d')
print(f"7---datetime实例.strftime(formate)：将datetime对象格式化输出{specific_datetime_format}")

# 将指定格式的文本转换为datetime对象
dt_str = '2023-04-22 15:30:00'
dt = datetime.strptime(dt_str, '%Y-%m-%d %H:%M:%S')
print(f"8---datetime.strptime(text,formate)：将文字转成datetiem对象{dt}")

# 使用timedelta类方法生成新datetime变量
future_date = today + timedelta(days=10)
print(f"9---（today + timedelta(days=10)）：十天后的日期是：{future_date}")

# datetime类型变量之间可以从事加减运算
date_diff = future_date - today
print(f"10---（future_date - today）：两个日期之间相差 {date_diff.days} 天")

# timezone类的utc属性显示时区信息
UTC = timezone.utc
print(f"11---timezone.utc：UTC 时区：{UTC}")

# timezone方法也可以通过timedelta方法进行时区变化
new_timezone = timezone(timedelta(hours=8))
print(f"12---timezone(timedelta(hours=8))：新时区（UTC+8）：{new_timezone}")

# 生成特定时区的当前时间
local_datetime = datetime.now(new_timezone)
print(f"13---datetime.now(new_timezone)：特定时区下的当前日期和时间：{local_datetime}")
# Out:
# 1---date.today()：今天的日期是2023-06-03
# 2---date(2022, 1, 1)：特定的日期是2022-01-01
# 3---today.weekday()：今天是一周中的第 6 天
# 4---time(14, 30, 45)：特定的时间是14:30:45
# 5---datetime.now()：现在的日期和时间是2023-06-03 08:59:48.720011
# 6---datetime(2022, 1, 1, 14, 30, 45)：特定的日期和时间是2022-01-01 14:30:45
# 7---datetime实例.strftime(formate)：将datetime对象格式化输出2022/01/01
# 8---datetime.strptime(text,formate)：将文字转成datetiem对象2023-04-22 15:30:00
# 9---（today + timedelta(days=10)）：十天后的日期是：2023-06-13
# 10---（future_date - today）：两个日期之间相差 10 天
# 11---timezone.utc：UTC 时区：UTC
# 12---timezone(timedelta(hours=8))：新时区（UTC+8）：UTC+08:00
# 13---datetime.now(new_timezone)：特定时区下的当前日期和时间：2023-06-03 08:59:48.721009+08:00

# %%
"""
【示例38】datetime模块应用2。
"""
import datetime

# 创建一个 datetime.date 类型的对象，表示今天的日期
today = datetime.date.today()
print("今天的日期是：", today)

# 创建一个 datetime.timedelta 类型的对象，表示一天的时间差
one_day = datetime.timedelta(days=1)

# 计算明天的日期
tomorrow = today + one_day
print("明天的日期是：", tomorrow)

# 创建一个 datetime.datetime 类型的对象，表示当前日期和时间
now = datetime.datetime.now()
print("当前日期和时间是：", now)

# 创建一个 datetime.timedelta 类型的对象，表示一小时的时间差
one_hour = datetime.timedelta(hours=1)
# 计算一小时后的时间
one_hour_later = now + one_hour
print("一小时后的时间是：", one_hour_later)
# Out:
# 今天的日期是： 2023-06-03
# 明天的日期是： 2023-06-04
# 当前日期和时间是： 2023-06-03 09:00:29.909153
# 一小时后的时间是： 2023-06-03 10:00:29.909153

# %%
"""
【示例39】os模块应用。
"""
import os

# 获取当前工作目录
current_dir = os.getcwd()
print(f'当前工作目录：{current_dir}')
# 切换工作目录
os.chdir('d:/backtrader_test/')
current_dir = os.getcwd()
print(f'当前工作目录：{current_dir}')
# 列出目录中的文件和子目录
dir_contents = os.listdir(current_dir)
print(f'当前目录中的文件和子目录：{dir_contents}')
# Out:
# 当前工作目录：D:\py_learn
# 当前工作目录：d:\backtrader_test
# 当前目录中的文件和子目录：['.idea', 'backtrader-海龟交易策略.py', 'backtrader_indicators.py', 'backtrader_indicators_1.py', 'backtrader_lifefunc.py', 'backtrader_no_ohlc.py', 'backtrader_parameters.py', 'backtrader_数据引用.py', 'backtrader_涨停持有5天.py', 'backtrader_画图.py', 'backtrader_网格交易2.py', 'backtrade_网格交易.py', 'bt_网格交易3.py', 'mydir', 'qmt_双均线策略.py', '涨停板统计.py']
